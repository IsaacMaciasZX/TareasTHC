# %% [markdown]
# <a href="https://colab.research.google.com/github/IsaacMaciasZX/TareasTHC/blob/main/Clase_5_NOviembre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="Red" face="Comic Sans MS,arial">
#   <h1 align="center"><i>Matplotlib </i></h1>
#   </font>
#
# > Elaborado por: Jesús Iván Coss Calderón. mat_ing_coss@ciencias.unam.mx

# %% [markdown]
# **Objetivo general**
#
# * Aprender los fundamentos de la biblioteca de Matplotlib
#
# **Objetivos particulares**
#
# * Entender el uso de los métodos de Matplotlib

# %% [markdown]
# [**Regresa al notebook principal**](https://github.com/seismomat/HerramientasComputacionales/blob/main/TemarioDePython/Temario%20de%20Python.ipynb)

# %% [markdown]
# <a name='c1'></a>
#
# ## Contenido
#
# - [¿Qué es Matplotlib?](#1)
#     - [Instalación de Matplotlib](#1-1)
#     - [Importando Matplotlib](#1-2)
# - [Graficando un objeto de NumPy](#2)
#     - [Dibujar puntos en coordenadas x e y](#2-1)
#     - [Dibujar puntos sin linea](#2-2)
#     - [Dibujar múltiples puntos](#2-3)
#     - [Puntos default](#2-4)
# - [Marcadores](#3)
#     - [Marcadores de referencia](#3-1)
#     - [Formato Strings fmt](#3-2)
#     - [Marker size](#3-3)
#     - [Marker color](#3-4)
# - [Estilo de línea](#4)
#     - [Color de la línea](#4-1)
#     - [Grosor de la línea](#4-2)
#     - [Múltiples líneas](#4-3)
# - [Etiquetas](#5)
#     - [Creando títulos](#5-1)
#     - [Fuentes](#5-2)
# - [Grid](#6)
#     - [Propiedades del grid](#6-1)
# - [Subplots](#7)
#     - [Título](#7-1)
#     - [Súper Título](#7-2)

# %% [markdown]
# <a name='1'></a>
#
# # ¿Qué es Matplotlib?
# [regresar al contenido](#c1)
#
# Matplotlib es una biblioteca de trazado de gráficos de bajo nivel en Python que sirve como una utilidad de visualización.
#
# Matplotlib fue creado por John D. Hunter.
#
# Matplotlib es de código abierto y podemos usarlo libremente.
#
# Matplotlib está principalmente escrito en Python, con algunas partes escritas en C, Objective-C y Javascript para garantizar la compatibilidad con diferentes plataformas.

# %% [markdown]
# <a name='1-1'></a>
#
# ## Instalación de Matplotlib
# [regresar al contenido](#c1)
#
# > pip install matplotlib

# %% [markdown]
# <a name='1-2'></a>
#
# ## Importando Matplotlib
# [regresar al contenido](#c1)
#
# > import matplotlib
#
# o también se puede importar con algún alias
#
# > import matplotlib.pyplot as plt

# %% [markdown]
# <a name='2'></a>
#
# # Graficando un objeto de NumPy
# [regresar al contenido](#c1)
#
# A continuación se dibuja una línea en un diagrama desde la posición (0,0) hasta la posición (6,250)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyblot as plt
import numpy as np

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8dc8324cb729> in <cell line: 1>()
# ----> 1 xpoints = np.array([0, 6])
#       2 ypoints = np.array([0, 250])
#       3
#       4 plt.plot(xpoints, ypoints)
#       5 plt.show()
#
# NameError: name 'np' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-f5079b2047f8> in <cell line: 1>()
# ----> 1 import matplotlib.pyblot as plt
#       2 import numpy as np
#       3
#       4 xpoints = np.array([0, 6])
#       5 ypoints = np.array([0, 250])
#
# ModuleNotFoundError: No module named 'matplotlib.pyblot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 15])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# <a name='2-1'></a>
#
# ## Dibujar puntos en coordenadas x e y
# [regresar al contenido](#c1)
#
# La función `plot()` se utiliza para dibujar puntos (marcadores) en un diagrama.
#
# De forma predeterminada, la función `plot()` dibuja una línea de punto a punto.
#
# La función toma parámetros para especificar los puntos en el diagrama.
#
# El parámetro 1 es un array que contiene los puntos en el eje x.
#
# El parámetro 2 es un array que contiene los puntos en el eje y.
#
# Si necesitamos trazar una línea desde (1, 3) hasta (8, 10), debemos pasar dos arrays [1, 8] y [3, 10] a la función plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# <a name='2-2'></a>
#
# ## Dibujar puntos sin linea
# [regresar al contenido](#c1)
#
# Para trazar solo los marcadores en un gráfico, puedes utilizar la notación de cadena abreviada `'o'`, que representa 'anillos'. Esto significa que solo se mostrarán los marcadores en lugar de una línea que los conecte

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 20])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
x=np.linspace(0,30,10)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
x=np.linspace(0,30,100) #mayor tercer numero, mejor grafica
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,x,y2)#se ahorra una linea poniendo todo aqui (?
plt.show()

# %%
x=np.linspace(0,30,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,x,y2,'o')
plt.show()

# %%
x=np.linspace(0,30,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,'o')
plt.plot(x,y2,'*') #los asteriscos grafican en forma de estrella (?
plt.show()

# %%
x=np.linspace(0,30,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,'r')
plt.plot(x,y2,'g') #letras para cambiarles color, inicial de cada color en ingles
plt.show()

# %%
x=np.linspace(0,30,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,'r')
plt.plot(x,y2,'g') #letras para cambiarles color, inicial de cada color en ingles
plt.show()

# %%
x=np.linspace(0,30,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,marker='o')
plt.plot(x,y2,marker='*') #traza lineas (une los puntos graficados)
plt.show()

# %%
x=np.linspace(0,30,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,marker='D')
plt.plot(x,y2,marker='3') #marcadores de diamante y triangulo
plt.show()

# %% [markdown]
# Consultar marcadores de referencia

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,30,100)
y1=x**2
plt.plot(x,y1,'m--.') #la linea de la grafica sale con forma de guion y punto, se puede con doble guion, con puro guion es linea solida
plt.show()
#con la inicial de color antes de la forma de grafica, se cambia el color lol
#ypoints = np.array([3, 8, 1, 10])

#plt.plot(x,y1)
#plt.plot(ypoints, 'o:r')
#plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,30,100)  #ms es abreviatira de markersize
y1=x**2
plt.plot(x,y1,'r',marker = '*', ms=800) #valor original es 10 para q se vea bn
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,30,50)
y1=x**2
plt.plot(x,y1,'r',marker = '*', ms=30,mec='m') #mec pa cambiarle de color (marker edge contour)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,30,100)
y1=x**2
plt.plot(x,y1,'r',marker = '*', ms=80,mfc='c') #mfc es markerfillcontour
plt.show()#en vez de 'r' puede ser linestyle= 'dotted'

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',linewidth= '20') #con linewidth ps es pa ajustar anchura de linea
plt.show()

# %%
#etiquetas (poner nombre a los ejes)
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
#con .label y ya sea el eje(x,y, o el titulo) se le asigna nombre
plt.xlabel("Chicharrones vendidos")
plt.ylabel("Hora del dia")
plt.title('Ventas de chicharrones')
plt.show()

# %%
#etiquetas (poner nombre a los ejes)
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20} #se pueden usar comillas dobles asi como simples (olvidé el dato)
font2 = {'family':'serif','color':'red','size':15}

plt.title("Ventas de chicharrones", fontdict = font1) #formato para cambiar y ajustar los niveles de tamaño, color, y asi.
plt.xlabel("Chicharrones vendidos", fontdict = font2)
plt.ylabel("Hora del dia", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#etiquetas (poner nombre a los ejes)
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20} #se pueden usar comillas dobles asi como simples (olvidé el dato)
font2 = {'family':'serif','color':'red','size':15}

plt.title("Ventas de chicharrones", fontdict = font1) #formato para cambiar y ajustar los niveles de tamaño, color, y asi.
plt.xlabel("Chicharrones vendidos", fontdict = font2)
plt.ylabel("Hora del dia", fontdict = font2)

plt.plot(x, y)
plt.grid() #Pa fondo de cuaderno, para rayado vertical u horizontal (plt.grid(axis=x o y))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'red','size':15}

plt.title("Ventas de chicharrones", fontdict = font1)
plt.xlabel("Chicharrones vendidos", fontdict = font2)
plt.ylabel("Hora del dia", fontdict = font2)

plt.plot(x, y)
plt.grid(axis='x',color='m',linestyle='--',linewidth=5) #mas ajustes de rayado o celda
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,30,100)
y1=np.sin(x)
y2=np.cos(x)


plt.subplot(1,2,1)
plt.plot(x,y1,x,y2)

plt.subplot(1,2,2)
plt.plot(x,y1)



plt.plot(x,y2)
plt.show()

# %% [markdown]
# <a name='2-3'></a>
#
# ## Dibujar múltiples puntos
# [regresar al contenido](#c1)
#
# Puedes trazar tantos puntos como desees, solo asegúrate de tener el mismo número de puntos en ambos ejes.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints,'o')
plt.show()

# %% [markdown]
# <a name='2-4'></a>
#
# ## Puntos default
# [regresar al contenido](#c1)
#
# Si no especificamos los puntos en el eje x, obtendrán los valores predeterminados 0, 1, 2, 3, etc., según la longitud de los puntos en el eje y.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints,'o')
plt.show()
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]

# %% [markdown]
# <a name='3'></a>
#
# # Marcadores
# [regresar al contenido](#c1)
#
# Puedes utilizar el argumento de palabra clave "marker" para resaltar cada punto con un marcador específico. Esto te permite personalizar la apariencia de los puntos en el gráfico, utilizando diferentes marcadores como círculos, cruces, triángulos, etc.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# <a name='3-1'></a>
#
# ## Marcadores de referencia
# [regresar al contenido](#c1)
#
# Estos son algunos de los marcadores que puedes utilizar con el argumento de palabra clave "marker" en Matplotlib para resaltar puntos en un gráfico:
#
# | Marcador | Descripción                    |
# |----------|--------------------------------|
# | 'o'      | Círculo                        |
# | '*'      | Estrella                       |
# | '.'      | Punto                          |
# | ','      | Píxel                          |
# | 'x'      | X                              |
# | 'X'      | X (relleno)                    |
# | '+'      | Más                            |
# | 'P'      | Más (relleno)                  |
# | 's'      | Cuadrado                       |
# | 'D'      | Diamante                       |
# | 'd'      | Diamante (delgado)             |
# | 'p'      | Pentágono                      |
# | 'H'      | Hexágono                       |
# | 'h'      | Hexágono                       |
# | 'v'      | Triángulo hacia abajo          |
# | '^'      | Triángulo hacia arriba         |
# | '<'      | Triángulo hacia la izquierda   |
# | '>'      | Triángulo hacia la derecha     |
# | '1'      | Triángulo hacia abajo          |
# | '2'      | Triángulo hacia arriba         |
# | '3'      | Triángulo hacia la izquierda   |
# | '4'      | Triángulo hacia la derecha     |
# | '|'      | Línea vertical                 |
# | '_'      | Línea horizontal               |

# %% [markdown]
# <a name='3-2'></a>
#
# ## Formato Strings fmt
# [regresar al contenido](#c1)
#
# También puedes utilizar la notación de cadena abreviada para especificar el marcador. Este parámetro también se llama "fmt" y se escribe con la siguiente sintaxis:
#
# marcador|línea|color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# Estos son algunos de los estilos de línea que puedes utilizar en Matplotlib para personalizar la apariencia de las líneas en tus gráficos:
#
# | Estilo de Línea | Descripción                               |
# |-----------------|-------------------------------------------|
# | '-'             | Línea sólida (predeterminada)             |
# | ':'             | Línea punteada                            |
# | '--'            | Línea discontinua (trazos largos y separados) |
# | '-.'            | Línea con trazos y puntos alternados      |

# %% [markdown]
# Estos son algunos de los códigos de colores que puedes utilizar en Matplotlib para especificar el color de los elementos en tus gráficos:
#
# | Color | Descripción |
# |-------|-------------|
# | 'r'   | Rojo        |
# | 'g'   | Verde       |
# | 'b'   | Azul        |
# | 'c'   | Cian        |
# | 'm'   | Magenta     |
# | 'y'   | Amarillo    |
# | 'k'   | Negro       |
# | 'w'   | Blanco      |

# %% [markdown]
# <a name='3-3'></a>
#
# ## Marker size
# [regresar al contenido](#c1)
#
# Puedes usar el argumento de palabra clave "markersize" o su versión abreviada "ms" para establecer el tamaño de los marcadores

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '*-b',ms = 20)
plt.show()

# %% [markdown]
# <a name='3-4'></a>
#
# ## Marker color
# [regresar al contenido](#c1)
#
# Puedes utilizar el argumento de palabra clave "markeredgecolor" o su versión abreviada "mec" para establecer el color del borde de los marcadores

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints,'o-k' , ms = 20, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# <a name='4'></a>
#
# # Estilo de línea
# [regresar al contenido](#c1)
#
# Puedes utilizar el argumento de palabra clave "linestyle" o su versión abreviada "ls" para cambiar el estilo de la línea trazada en el gráfico.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, ls = ':')

# %% [markdown]
# <a name='4-1'></a>
#
# ## Color de línea
# [regresar al contenido](#c1)
#
# Puedes utilizar el argumento de palabra clave "color" o su versión abreviada "c" para establecer el color de la línea en el gráfico.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# <a name='4-2'></a>
#
# ## Grosor de la línea
# [regresar al contenido](#c1)

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# <a name='4-3'></a>
#
# ## Múltiples líneas
# [regresar al contenido](#c1)

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# <a name='5'></a>
#
# # Etiquetas
# [regresar al contenido](#c1)
#
# Con Pyplot, puedes utilizar las funciones `xlabel()` y `ylabel()` para establecer una etiqueta para los ejes x e y en un gráfico. Estas funciones te permiten agregar descripciones claras a tus gráficos para que los datos sean más comprensibles.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# <a name='5-1'></a>
#
# ## Creando títulos
# [regresar al contenido](#c1)
#
# Con Pyplot, puedes utilizar la función title() para establecer un título para tu gráfico. El título proporciona información adicional sobre el contenido del gráfico y puede ayudar a los espectadores a comprender su propósito.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# <a name='5-2'></a>
#
# ## Fuentes
# [regresar al contenido](#c1)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# <a name='6'></a>
#
# # Grid
# [regresar al contenido](#c1)
#
# Con Pyplot, puedes utilizar la función `grid()` para agregar líneas de cuadrícula a tu gráfico. Las líneas de cuadrícula son útiles para ayudar a visualizar y medir los valores en el gráfico, lo que facilita la interpretación de los datos representados.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# Puedes utilizar el parámetro `"axis"` en la función `grid()` para especificar qué líneas de cuadrícula mostrar. Los valores válidos son: 'x', 'y' y 'both' (ambos). El valor predeterminado es 'both' (ambos), lo que significa que se mostrarán líneas de cuadrícula tanto en el eje x como en el eje y. Sin embargo, puedes personalizarlo según tus necesidades para mostrar solo las líneas de cuadrícula que desees.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# <a name='6-1'></a>
#
# # Propiedades del grid
# [regresar al contenido](#c1)
#
# También puedes establecer las propiedades de línea de la cuadrícula utilizando la función `grid()`, de la siguiente manera: `grid(color='color', linestyle='linestyle', linewidth=number)`. Esto te permite personalizar el color, el estilo de línea y el grosor de las líneas de la cuadrícula en tu gráfico. Puedes reemplazar 'color' con el nombre del color deseado (por ejemplo, 'blue' para azul), 'linestyle' con el estilo de línea deseado (por ejemplo, 'dotted' para punteado) y 'number' con el grosor de la línea deseado (por ejemplo, 1.5 para un grosor de línea de 1.5 puntos).

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# <a name='7'></a>
#
# # Subplots
# [regresar al contenido](#c1)

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# La función `subplot()` toma tres argumentos que describen la disposición de la figura.
#
# La disposición se organiza en filas y columnas, que están representadas por el primer y segundo argumento.
#
# El tercer argumento representa el índice del gráfico actual.

# %%
plt.subplot(1, 2, 1)
# La figura tiene 1 fila, 2 columnas y este gráfico es el primer gráfico.
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1, 2, 2)
# La figura tiene 1 fila, 2 columnas y este gráfico es el segundo gráfico.
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dibuja 2 gráficos uno encima del otro:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# Puedes dibujar tantos gráficos como desees en una figura, solo describe el número de filas, columnas y el índice del gráfico.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# <a name='7-1'></a>
#
# # Título
# [regresar al contenido](#c1)
#
# Puedes agregar el título de cada subfigura con el comando `title()`

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Salidas")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Entradas")

plt.show()

# %% [markdown]
# <a name='7-2'></a>
#
# # Súper título
# [regresar al contenido](#c1)
#
# Puedes agregar el título de cada subfigura con el comando `suptitle()`

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Salidas")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Entradas")

plt.suptitle("Mi tienda")
plt.show()
